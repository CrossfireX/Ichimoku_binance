# %%
import pandas as pd
import mplfinance as mpf

# %%
market = ['BTCUSDT','ETHUSDT','XRPUSDT','LINKUSDT']
timeframe = ['1h','4h','12h','1d']

# %%
def read(market, timeframe):
    file = 'data_ichi/'+market+'_'+timeframe+'_add.csv'
    df = pd.read_csv(file, index_col='OpenTime', parse_dates=True)
    print('--------------------------------------------')
    print(market+' • '+timeframe)
    df = df[250:]
    return df

# %%
def plot (df):
    a = df[['tenkan_sen']]
    b = df[['kijun_sen']]
    c = df[['chikou_span']]
    d = df[['senkou_span_a']]
    e = df[['senkou_span_b']]

    apds = [ mpf.make_addplot(a,color='turquoise'),
             mpf.make_addplot(b,color='deeppink'),
             mpf.make_addplot(c,color='orange',alpha=0.8,linestyle='dotted'),
             mpf.make_addplot(d,color='turquoise',alpha=0.3,),
             mpf.make_addplot(e,color='deeppink',alpha=0.3,),
             #mpf.make_addplot(high_signal,type='scatter',markersize=200,marker='v'),
             #mpf.make_addplot((df['PercentB']),panel=1,color='g',linestyle='dotted')
           ]
    
    mpf.plot(df,
             addplot=apds,
             fill_between=dict(y1=df['senkou_span_a'].values,y2=df['senkou_span_b'].values, alpha=0.15,color='grey'),
             #fill_between=dict(y1=df['senkou_span_a'].values,y2=df['senkou_span_b'].values,where = df['senkou_span_a']> df['senkou_span_b'], alpha=0.3,color='g'),
             #fill_between=dict(y1=df['senkou_span_a'].values,y2=df['senkou_span_b'].values,where = df['senkou_span_b']> df['senkou_span_a'], alpha=0.3,color='r'),
             type='candle',volume=True, style='classic',figsize=(20,9))
    return df

# %%
def run():
    df = read(x,y)
    tenkan = df.iloc[-31,df.columns.get_loc("tenkan_sen")]
    kijun = df.iloc[-31,df.columns.get_loc("kijun_sen")]
    close = df.iloc[-31,df.columns.get_loc("Close")]
    sena = df.iloc[-1,df.columns.get_loc("senkou_span_a")]
    senb = df.iloc[-1,df.columns.get_loc("senkou_span_b")]
    
    print("Price:",close)
    print("Tenkan:",tenkan)
    print("Kijun:",kijun)
    print("Senkou:",senb,'-',sena)
    print('--------------------------------------------')
    plot(df)

# %% [markdown]
# # Plot the data

# %%
for x in market:
    for y in timeframe:
        run()
# Out:
# --------------------------------------------
# BTCUSDT • 1h
# Price: 20778.46
# Tenkan: 20082.865
# Kijun: 19947.2
# Senkou: 19408.79 - 20015.0325
# --------------------------------------------
# --------------------------------------------
# BTCUSDT • 4h
# Price: 20780.06
# Tenkan: 19918.215
# Kijun: 19218.88
# Senkou: 18651.755 - 19568.5475
# --------------------------------------------
# --------------------------------------------
# BTCUSDT • 12h
# Price: 20780.06
# Tenkan: 19218.88
# Kijun: 18526.715
# Senkou: 16105.825 - 18872.7975
# --------------------------------------------
# --------------------------------------------
# BTCUSDT • 1d
# Price: 20780.06
# Tenkan: 18651.755
# Kijun: 16105.825
# Senkou: 15345.215 - 17378.79
# --------------------------------------------
# --------------------------------------------
# ETHUSDT • 1h
# Price: 622.98
# Tenkan: 604.855
# Kijun: 602.3
# Senkou: 586.05 - 603.5775
# --------------------------------------------
# --------------------------------------------
# ETHUSDT • 4h
# Price: 622.98
# Tenkan: 602.3
# Kijun: 579.7149999999998
# Senkou: 564.71 - 591.0074999999998
# --------------------------------------------
# --------------------------------------------
# ETHUSDT • 12h
# Price: 622.98
# Tenkan: 579.7149999999998
# Kijun: 546.1500000000002
# Senkou: 500.485 - 562.9325
# --------------------------------------------
# --------------------------------------------
# ETHUSDT • 1d
# Price: 622.99
# Tenkan: 564.71
# Kijun: 500.485
# Senkou: 472.06000000000006 - 532.5975000000002
# --------------------------------------------
# --------------------------------------------
# XRPUSDT • 1h
# Price: 0.51883
# Tenkan: 0.484105
# Kijun: 0.484105
# Senkou: 0.512095 - 0.484105
# --------------------------------------------
# --------------------------------------------
# XRPUSDT • 4h
# Price: 0.51883
# Tenkan: 0.484105
# Kijun: 0.53061
# Senkou: 0.55911 - 0.5073575
# --------------------------------------------
# --------------------------------------------
# XRPUSDT • 12h
# Price: 0.51878
# Tenkan: 0.53061
# Kijun: 0.5306150000000001
# Senkou: 0.5042 - 0.5306125
# --------------------------------------------
# --------------------------------------------
# XRPUSDT • 1d
# Price: 0.51867
# Tenkan: 0.55911
# Kijun: 0.5042
# Senkou: 0.5000600000000001 - 0.531655
# --------------------------------------------
# --------------------------------------------
# LINKUSDT • 1h
# Price: 13.315999999999999
# Tenkan: 12.8695
# Kijun: 12.8695
# Senkou: 12.51355 - 12.8695
# --------------------------------------------
# --------------------------------------------
# LINKUSDT • 4h
# Price: 13.3166
# Tenkan: 12.8695
# Kijun: 12.4918
# Senkou: 13.1314 - 12.68065
# --------------------------------------------
# --------------------------------------------
# LINKUSDT • 12h
# Price: 13.3166
# Tenkan: 12.4918
# Kijun: 13.84195
# Senkou: 13.07 - 13.166875
# --------------------------------------------
# --------------------------------------------
# LINKUSDT • 1d
# Price: 13.3166
# Tenkan: 13.1314
# Kijun: 13.07
# Senkou: 12.5323 - 13.1007
# --------------------------------------------
