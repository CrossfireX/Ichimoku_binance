# %%
import pandas as pd
import mplfinance as mpf

# %%
market = ['BTCUSDT','ETHUSDT','XRPUSDT','LINKUSDT']
timeframe = ['1h','4h','12h','1d']

# %%
def read(market, timeframe):
    file = 'data_ichi/'+market+'_'+timeframe+'_add.csv'
    df = pd.read_csv(file, index_col='OpenTime', parse_dates=True)
    print('--------------------------------------------')
    print(market+' • '+timeframe)
    df = df[250:]
    return df

# %%
def plot (df):
    a = df[['tenkan_sen']]
    b = df[['kijun_sen']]
    c = df[['chikou_span']]
    d = df[['senkou_span_a']]
    e = df[['senkou_span_b']]

    apds = [ mpf.make_addplot(a,color='turquoise'),
             mpf.make_addplot(b,color='deeppink'),
             mpf.make_addplot(c,color='orange',alpha=0.8,linestyle='dotted'),
             mpf.make_addplot(d,color='turquoise',alpha=0.3,),
             mpf.make_addplot(e,color='deeppink',alpha=0.3,),
             #mpf.make_addplot(high_signal,type='scatter',markersize=200,marker='v'),
             #mpf.make_addplot((df['PercentB']),panel=1,color='g',linestyle='dotted')
           ]
    
    mpf.plot(df,
             addplot=apds,
             fill_between=dict(y1=df['senkou_span_a'].values,y2=df['senkou_span_b'].values, alpha=0.15,color='grey'),
             #fill_between=dict(y1=df['senkou_span_a'].values,y2=df['senkou_span_b'].values,where = df['senkou_span_a']> df['senkou_span_b'], alpha=0.3,color='g'),
             #fill_between=dict(y1=df['senkou_span_a'].values,y2=df['senkou_span_b'].values,where = df['senkou_span_b']> df['senkou_span_a'], alpha=0.3,color='r'),
             type='candle',volume=True, style='classic',figsize=(20,9))
    return df

# %%
def run():
    df = read(x,y)
    tenkan = df.iloc[-31,df.columns.get_loc("tenkan_sen")]
    kijun = df.iloc[-31,df.columns.get_loc("kijun_sen")]
    close = df.iloc[-31,df.columns.get_loc("Close")]
    sena = df.iloc[-1,df.columns.get_loc("senkou_span_a")]
    senb = df.iloc[-1,df.columns.get_loc("senkou_span_b")]
    
    print("Price:",close)
    print("Tenkan:",tenkan)
    print("Kijun:",kijun)
    print("Senkou:",senb,'-',sena)
    print('--------------------------------------------')
    plot(df)

# %% [markdown]
# # Plot the data

# %%
for x in market:
    for y in timeframe:
        run()
# Out:
# --------------------------------------------
# BTCUSDT • 1h
# Price: 23144.94
# Tenkan: 22255.5
# Kijun: 21425.0
# Senkou: 21081.21 - 21840.25
# --------------------------------------------
# --------------------------------------------
# BTCUSDT • 4h
# Price: 23144.94
# Tenkan: 21414.485
# Kijun: 20686.165
# Senkou: 20132.74 - 21050.325
# --------------------------------------------
# --------------------------------------------
# BTCUSDT • 12h
# Price: 23144.94
# Tenkan: 20686.165
# Kijun: 19994.0
# Senkou: 17603.98 - 20340.0825
# --------------------------------------------
# --------------------------------------------
# BTCUSDT • 1d
# Price: 23152.22
# Tenkan: 20332.78
# Kijun: 17603.98
# Senkou: 16812.5 - 18968.38
# --------------------------------------------
# --------------------------------------------
# ETHUSDT • 1h
# Price: 662.89
# Tenkan: 645.585
# Kijun: 624.395
# Senkou: 610.9449999999998 - 634.99
# --------------------------------------------
# --------------------------------------------
# ETHUSDT • 4h
# Price: 662.89
# Tenkan: 622.905
# Kijun: 600.3199999999998
# Senkou: 581.965 - 611.6125
# --------------------------------------------
# --------------------------------------------
# ETHUSDT • 12h
# Price: 662.88
# Tenkan: 600.3199999999998
# Kijun: 563.405
# Senkou: 517.74 - 581.8625
# --------------------------------------------
# --------------------------------------------
# ETHUSDT • 1d
# Price: 662.88
# Tenkan: 588.4
# Kijun: 517.74
# Senkou: 489.31500000000005 - 553.0699999999998
# --------------------------------------------
# --------------------------------------------
# XRPUSDT • 1h
# Price: 0.6
# Tenkan: 0.561345
# Kijun: 0.52355
# Senkou: 0.52355 - 0.5424475000000001
# --------------------------------------------
# --------------------------------------------
# XRPUSDT • 4h
# Price: 0.6
# Tenkan: 0.52355
# Kijun: 0.5269199999999999
# Senkou: 0.55911 - 0.5252349999999999
# --------------------------------------------
# --------------------------------------------
# XRPUSDT • 12h
# Price: 0.5999399999999999
# Tenkan: 0.52385
# Kijun: 0.5306150000000001
# Senkou: 0.5042 - 0.5272325
# --------------------------------------------
# --------------------------------------------
# XRPUSDT • 1d
# Price: 0.5999399999999999
# Tenkan: 0.55911
# Kijun: 0.5042
# Senkou: 0.5000600000000001 - 0.531655
# --------------------------------------------
# --------------------------------------------
# LINKUSDT • 1h
# Price: 14.0146
# Tenkan: 13.6663
# Kijun: 13.2935
# Senkou: 13.07645 - 13.4799
# --------------------------------------------
# --------------------------------------------
# LINKUSDT • 4h
# Price: 14.0146
# Tenkan: 13.2935
# Kijun: 12.85255
# Senkou: 13.1314 - 13.073025
# --------------------------------------------
# --------------------------------------------
# LINKUSDT • 12h
# Price: 14.0146
# Tenkan: 12.85255
# Kijun: 13.84195
# Senkou: 13.07 - 13.34725
# --------------------------------------------
# --------------------------------------------
# LINKUSDT • 1d
# Price: 14.017999999999999
# Tenkan: 13.1314
# Kijun: 13.07
# Senkou: 12.5323 - 13.1007
# --------------------------------------------
